# %% [markdown]
# <a href="https://colab.research.google.com/github/imranjia/w3schoolPython/blob/main/Python_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World22!")
# Out:
# Hello, World22!

# %%
print("hello")
# Out:
# hello

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
print("Python Get Started")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-371497675.py in <cell line: 0>()
# ----> 1 Print("Python Get Started")
#
# NameError: name 'Print' is not defined

# %%
print("Use small letter p in python")
# Out:
# Use small letter p in python

# %%
import sys
print(sys.version)
# Out:
#   File "/tmp/ipython-input-730223247.py", line 1
#     python version
#            ^
# SyntaxError: invalid syntax
